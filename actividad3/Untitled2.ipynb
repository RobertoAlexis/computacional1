# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df0 = pd.read_csv('dfunjun222.txt' , skiprows=2, sep='\s+')

# %%
df0
# Out:
#                                                                                                      -----------------------------------------------------------------------------
# PRES                                               HGHT  TEMP  DWPT  RELH MIXR DRCT SKNT THTA  THTE                                                THTV
# hPa                                                m     C     C     %    g/kg deg  knot K     K                                                      K
# -----------------------------------------------... NaN   NaN   NaN   NaN  NaN  NaN  NaN  NaN   NaN                                                  NaN
# 773.0                                              2313  15.6  9.6   67   9.80 0    0    310.8 341.1                                              312.6
# 764.0                                              2411  15.0  9.4   69   9.76 150  1    311.2 341.5                                              313.0
# ...

# %%
df = pd.DataFrame(df0)

# %%
df.dtypes
# Out:
# -----------------------------------------------------------------------------    object
# dtype: object

# %%
x = df0.PRES
y = df0.HGHT

plt.figure()
plt.plot(x, y)
 
plt.xlabel('TEMPERATURA')
plt.ylabel('ALTURA')
 
plt.title('Temperatura como funcion de la altura')

plt.grid(True)
 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-0649b3dbbbab> in <module>()
# ----> 1 x = df0.PRES
#       2 y = df0.HGHT
#       3
#       4 plt.figure()
#       5 plt.plot(x, y)
#
# /opt/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    3079             if name in self._info_axis:
#    3080                 return self[name]
# -> 3081             return object.__getattribute__(self, name)
#    3082
#    3083     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'PRES'
