# %%
#Vamos a importar las bibiliotecas de pandas, numpy y matplot
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#vamos a leer los dos archivos de Abha para poder trabajar con ellos
Dec0=pd.read_csv('vologradodic00.txt', skiprows=8, sep='\s+')
Jun0=pd.read_csv('vologradojun00.txt', skiprows=9, sep='\s+')
#Como nos saltamos los títulos de las columnas, las volvemos a nombrar:
Dec0.columns=['PRES','HGHT','TEMP','DWPT','RELH','MIXR','DRCT','SKNT','THTA','THTE','THTV']
Jun0.columns=['PRES','HGHT','TEMP','DWPT','RELH','MIXR','DRCT','SKNT','THTA','THTE','THTV']

# %%
Dec0.head()
# Out:
#     PRES  HGHT  TEMP  DWPT  RELH  MIXR  DRCT  SKNT   THTA   THTE   THTV
# 0  925.0   819  -5.9  -9.5    76  2.02   275    12  273.3  279.0  273.6
# 1  909.0   955  -6.9  -9.6    81  2.04   285    16  273.6  279.4  273.9
# 2  885.0  1164  -8.5  -9.8    90  2.06   265    19  274.1  279.9  274.4
# 3  850.0  1478  -6.7 -12.7    62  1.70   235    25  279.1  284.1  279.4
# 4  835.0  1617  -6.1 -23.1    25  0.72   232    24  281.2  283.4  281.3

# %%
Jun0.head()
# Out:
#     PRES  HGHT  TEMP  DWPT  RELH  MIXR  DRCT  SKNT   THTA   THTE   THTV
# 0  942.0   552  20.2  11.2    56  8.94   318    19  298.4  324.8  300.0
# 1  925.0   708  19.0  11.0    60  8.98   315    19  298.7  325.3  300.4
# 2  872.0  1214  16.4   8.4    59  7.99   277    14  301.1  325.1  302.6
# 3  850.0  1431  14.6   7.6    63  7.76   260    12  301.4  324.7  302.8
# 4  839.0  1539  13.8   7.0    64  7.56   255    12  301.7  324.4  303.1

# %%
#No todo el documento es la tabla de datos que queremos usar, así que vamos a droppear la información que hay debajo de 
#las tablas.
#
#Drop sirve para slaltarnos cierto número de filas, no las eliminamos del documento, simplemente las saltamos al momento
#de leerlas.
Dec0=Dec0[:-21]

# %%
Dec0.head(100)
# Out:
#      PRES  HGHT  TEMP  DWPT  RELH  MIXR  DRCT  SKNT   THTA   THTE   THTV
# 0   925.0   819  -5.9  -9.5    76  2.02   275    12  273.3  279.0  273.6
# 1   909.0   955  -6.9  -9.6    81  2.04   285    16  273.6  279.4  273.9
# 2   885.0  1164  -8.5  -9.8    90  2.06   265    19  274.1  279.9  274.4
# 3   850.0  1478  -6.7 -12.7    62  1.70   235    25  279.1  284.1  279.4
# 4   835.0  1617  -6.1 -23.1    25  0.72   232    24  281.2  283.4  281.3
# 5   796.0  1990  -7.2 -27.1    19  0.52   225    19  283.8  285.5  283.9
# 6   743.0  2526  -8.9 -32.9    12  0.32   236    26  287.7  288.8  287.7
# 7   700.0  2984 -12.9 -34.9    14  0.28   245    31  288.2  289.1  288.2
# 8   684.0  3159 -14.3 -35.3    15  0.28   242    32  288.5  289.5  288.6
# 9   629.0  3789 -17.7 -20.0    82  1.25   232    36  291.6  295.6  291.9
# 10  572.0  4487 -21.6 -23.3    86  1.03   220    41  295.0  298.4  295.2
# 11  519.0  5201 -25.7 -26.7    91  0.83   224    45  298.4  301.2  298.6
# 12  500.0  5470 -27.1 -28.5    88  0.73   225    47  299.9  302.4  300.1
# 13  400.0  7040 -38.7 -41.4    76  0.26   235    66  304.6  305.6  304.7

# %%
Dec0.dtypes
# Out:
# PRES    float64
# HGHT      int64
# TEMP    float64
# DWPT    float64
# RELH      int64
# MIXR    float64
# DRCT      int64
# SKNT      int64
# THTA    float64
# THTE    float64
# THTV    float64
# dtype: object

# %%
Jun0.dtypes
# Out:
# PRES    float64
# HGHT      int64
# TEMP    float64
# DWPT    float64
# RELH      int64
# MIXR    float64
# DRCT      int64
# SKNT      int64
# THTA    float64
# THTE    float64
# THTV    float64
# dtype: object

# %%
Jun0=Jun0[:-25]

# %%
#Queremos leer nuestros datos en la tabla, pero estos se leen como objeto (como el tipo CHARACTER de Fortran).
#Para convertirlos de objeto a flotante se usa la función:
#
#Primero con Diciembre
ConjuntoCol=['PRES','HGHT','TEMP','DWPT','RELH','MIXR','DRCT','SKNT','THTA','THTE','THTV']
Dec0[ConjuntoCol]=Dec0[ConjuntoCol].apply(pd.to_numeric,errors='coerce',axis=1)

# %%
Jun0.head(100)
# Out:
#      PRES  HGHT  TEMP  DWPT  RELH  MIXR  DRCT  SKNT   THTA   THTE   THTV
# 0   942.0   552  20.2  11.2    56  8.94   318    19  298.4  324.8  300.0
# 1   925.0   708  19.0  11.0    60  8.98   315    19  298.7  325.3  300.4
# 2   872.0  1214  16.4   8.4    59  7.99   277    14  301.1  325.1  302.6
# 3   850.0  1431  14.6   7.6    63  7.76   260    12  301.4  324.7  302.8
# 4   839.0  1539  13.8   7.0    64  7.56   255    12  301.7  324.4  303.1
# 5   740.0  2577   5.8   1.6    75  5.84   270    27  304.0  321.9  305.0
# 6   700.0  3036   2.2  -0.8    81  5.18   265    25  304.9  320.9  305.9
# 7   690.0  3152   2.0  -1.2    79  5.11   263    25  305.9  321.8  306.9
# 8   611.0  4122  -5.1  -8.5    77  3.31   250    22  308.6  319.2  309.2
# 9   583.0  4487  -7.6 -11.1    76  2.83   245    21  309.8  319.0  310.3
# 10  548.0  4969 -10.9 -14.5    75  2.28   273    21  311.4  319.0  311.9
# 11  534.0  5168 -11.5 -19.1    54  1.60   285    21  313.0  318.5  313.3
# 12  529.0  5240 -11.7 -20.7    47  1.40   284    22  313.6  318.4  313.9
# 13  500.0  5670 -14.3 -22.3    51  1.29   280    29  315.5  320.0  315.8
# 14  436.0  6691 -20.3 -26.3    59  1.03   259    30  320.5  324.2  320.7
# 15  400.0  7320 -24.9 -31.9    52  0.66   245    31  322.5  325.0  322.7
# 16  397.0  7373 -25.3 -32.3    52  0.64   245    31  322.7  325.1  322.8
# 17  354.0  8178 -31.9 -39.0    50  0.37   260    33  324.5  325.9  324.6
# 18  300.0  9340 -41.5 -48.5    47  0.16   245    31  326.8  327.4  326.8
# 19  293.0  9499 -43.7 -50.7    46  0.12   246    32  325.9  326.4  325.9

# %%
Dec0.dtypes
# Out:
# PRES    float64
# HGHT    float64
# TEMP    float64
# DWPT    float64
# RELH    float64
# MIXR    float64
# DRCT    float64
# SKNT    float64
# THTA    float64
# THTE    float64
# THTV    float64
# dtype: object

# %%
Jun0.dtypes
# Out:
# PRES    float64
# HGHT      int64
# TEMP    float64
# DWPT    float64
# RELH      int64
# MIXR    float64
# DRCT      int64
# SKNT      int64
# THTA    float64
# THTE    float64
# THTV    float64
# dtype: object

# %%
#Vamos a darle estructura a los datos
#
#Primero Diciembre
Dec=pd.DataFrame(Dec0)

# %%
#Luego Junio
Jun=pd.DataFrame(Jun0)

# %%
#Vamos a empezar a gráficar.
#
#La primera es una gráfica de presión como función de la altura
#
#Diciembre
Dec1=Dec[['HGHT','PRES']]
plt.figure(); Dec1.plot(x='PRES'); plt.legend(loc='best')
plt.title('Gráfica de Presión como Función de la Altura')
plt.xlabel('Presión (hPa)')
plt.ylabel('Altura (m)')
plt.xlim([100,800])
plt.grid(True)
plt.show()

# %%
#Junio
Jun1=Jun[['HGHT','PRES']]
plt.figure(); Jun1.plot(x='PRES'); plt.legend(loc='best')
plt.title('Gráfica de Presión como Función de la Altura')
plt.xlabel('Presión (hPa)')
plt.ylabel('Altura (m)')
plt.xlim([0,800])
plt.grid(True)
plt.show()

# %%
#Gráfica de la temperatura (TEMP) y temperatura de rocío (DEWPT), como función de la altura
#
#Diciembre
Dec1=Dec[['HGHT','TEMP','DWPT']]
plt.figure(); Dec1.plot(x='HGHT'); plt.legend(loc='best')
plt.title('Gráfica de la temperatura y temperatura de rocío como función de la altura')
plt.xlabel('Altura (m)')
plt.ylabel('Temperatura (°C)')
plt.grid(True)
plt.show()

# %%
#Junio
Jun1=Jun[['HGHT','TEMP','DWPT']]
plt.figure();Jun1.plot(x='HGHT'); plt.legend(loc='best')
plt.title('Gráfica de la temperatura y temperatura de rocío como función de la altura')
plt.xlabel('Altura (m)')
plt.ylabel('Temperatura (°C)')
plt.grid(True)
plt.show()

# %%
#Gráfica de la rapidez de los vientos en nudos (SKNT)
#
#Diciembre
Dec1=Dec[['HGHT','SKNT']]
plt.figure(); Dec1.plot(x='HGHT'), plt.legend(loc='best')
plt.title('Gráfica de la rapidez de los vientos en nudos')
plt.ylabel('Altura(m)')
plt.xlabel('Rápidez de los Vientos (Nudos)')
plt.grid(True)
plt.show()
