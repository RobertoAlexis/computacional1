# %%
import pandas as pd
import numpy as np
from datetime import datetime

# %%
# Leer archivo de datos
# Convertir las columnas Temp, de objeto a número
df = pd.read_csv("sargento-salinidad-2702181.csv", header=None,skiprows=2, names=['#','DateTime','CondHigh','Temp','SpecificConductance','Salinity'])
#df.DateTime=pd.to_numeric(df.DateTime, errors='coerce')
df.CondHigh=pd.to_numeric(df.CondHigh, errors='coerce')
df.head()
# Out:
#    #             DateTime  CondHigh   Temp  SpecificConductance  Salinity
# 0  1  02/04/2018 09:30:00   50782.6  17.53              59295.4   39.6728
# 1  2  02/04/2018 09:45:00   50617.2  17.33              59362.4   39.7235
# 2  3  02/04/2018 10:00:00   50646.3  17.23              59526.8   39.8482
# 3  4  02/04/2018 10:15:00   50772.9  17.17              59753.7   40.0203
# 4  5  02/04/2018 10:30:00   51007.8  17.14              60068.6   40.2595

# %%
# Convertir la cadena de caracteres 'Date' en variable temporal 'NDate'
df['Ndate'] = pd.to_datetime(df['DateTime'], format='%m/%d/%Y %H:%M:%S')
df['month'] = df['Ndate'].dt.month
df.head()
# Out:
#    #             DateTime  CondHigh   Temp  SpecificConductance  Salinity  \
# 0  1  02/04/2018 09:30:00   50782.6  17.53              59295.4   39.6728
# 1  2  02/04/2018 09:45:00   50617.2  17.33              59362.4   39.7235
# 2  3  02/04/2018 10:00:00   50646.3  17.23              59526.8   39.8482
# 3  4  02/04/2018 10:15:00   50772.9  17.17              59753.7   40.0203
# 4  5  02/04/2018 10:30:00   51007.8  17.14              60068.6   40.2595
#
#                 Ndate  month
# 0 2018-02-04 09:30:00      2
# 1 2018-02-04 09:45:00      2
# 2 2018-02-04 10:00:00      2
# 3 2018-02-04 10:15:00      2
# 4 2018-02-04 10:30:00      2

# %%
# graficar Boxplots por mes
# Biblioteca Seaborn
import seaborn as sns
import matplotlib.pyplot as plt
ax = sns.boxplot(x="month", y="Salinity", data=df)
plt.show()

# %%
# graficar Boxplots por mes
# Biblioteca Seaborn
import seaborn as sns
import matplotlib.pyplot as plt
ax = sns.boxplot(x="month", y="Temp", data=df)
plt.show()

# %%
import seaborn as sns
sns.set(style="darkgrid", color_codes=True)

g = sns.jointplot("Temp", "Salinity", data=df, kind="reg",
                   color="r", size=7)
plt.show(g)
